# %%
pip install ultralytics==8.0.196
# Out:
# ...
#   Using cached ultralytics-8.0.196-py3-none-any.whl.metadata (31 kB)
# ...
# Using cached ultralytics-8.0.196-py3-none-any.whl (631 kB)
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.14
#     Uninstalling ultralytics-8.1.14:
#       Successfully uninstalled ultralytics-8.1.14
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import settings
settings.reset()

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="a2fWzvuByr4vs1xkkJvd")
project = rf.workspace("dms-fnrsu").project("sejong")
dataset = project.version(3).download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="a2fWzvuByr4vs1xkkJvd")
project = rf.workspace("dms-fnrsu").project("bicycle-human")
dataset = project.version(2).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import torch
print(torch.__version__)
# Out:
# 1.12.1

# %%
pip show torchvision
# Out:
# Name: torchvision
# Version: 0.13.1a0
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: /home/pjs/anaconda3/envs/CNN/lib/python3.10/site-packages
# Requires: numpy, pillow, requests, torch, typing-extensions
# Required-by: ultralytics
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

print("OpenCV version:", cv2.__version__)
# Out:
# OpenCV version: 4.6.0

# %%
pip install torch==1.11
# Out:
# ...
#   Using cached torch-1.11.0-cp310-cp310-manylinux1_x86_64.whl (750.6 MB)
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show torch
# Out:
# Name: torch
# Version: 1.11.0
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /home/pjs/anaconda3/envs/CNN/lib/python3.10/site-packages
# Requires: typing-extensions
# Required-by: thop, torchaudio, torchvision, ultralytics
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchvision==0.12
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 9.3 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1a0
#     Uninstalling torchvision-0.13.1a0:
#       Successfully uninstalled torchvision-0.13.1a0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# 디렉토리 경로 설정, 실제 경로로 수정해야 함
label_dir = '/home/pjs/workspace/labels-1 - 복사본'

# 디렉토리 내 모든 파일에 대해 반복
for filename in os.listdir(label_dir):
    # 파일 경로 조합
    file_path = os.path.join(label_dir, filename)
    # 텍스트 파일이면 처리
    if os.path.isfile(file_path) and file_path.endswith('.txt'):
        # 파일 읽기
        with open(file_path, 'r') as file:
            lines = file.readlines()
        lines = ['0' + line[1:] if line.startswith('1') else line for line in lines]

        
        # 변경된 내용으로 파일 쓰기
        with open(file_path, 'w') as file:
            file.writelines(lines)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="a2fWzvuByr4vs1xkkJvd")
project = rf.workspace("dms-fnrsu").project("bicycle-human")
dataset = project.version(3).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to bicycle-human-3 in yolov8:: 100%|██████████| 1232/1232 [00:00<00:00, 10599.87it/s]

# %%
import cv2
from ultralytics import YOLO

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv8x model
model = YOLO('yolov8x.yaml').load('yolov8x.pt')

# Train the model with your dataset
results = model.train(data='/home/pjs/workspace/SEJONG/bicycle-human-3/data.yaml', epochs=100, imgsz=640)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
# ...

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=/home/pjs/workspace/SEJONG/bicycle-human-2/data.yaml epochs=50 imgsz=640 pretrained=True  patience=5
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-1.11.0+cu102 CPU (Intel Core(TM) i7-10700K 3.80GHz)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
# Load the trained YOLO model with custom weights from 'best.pt'
model = YOLO('/home/pjs/workspace/SEJONG/realrun/detect/train38/weights/last.pt')

# %%
# 객체 탐지
results = model('/home/pjs/workspace/SEJONG/bicycle-human-3/train/images/240122085733-0010_jpg.rf.580ca191e94d919d4e0faaa5662c2eef.jpg')
# Out:
# image 1/1 /home/pjs/workspace/SEJONG/bicycle-human-3/train/images/240122085733-0010_jpg.rf.580ca191e94d919d4e0faaa5662c2eef.jpg: 640x640 22 persons, 577.5ms
# Speed: 1.0ms preprocess, 577.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt

# %%
# 결과 출력
res_plotted = results[0].plot()

plt.figure(figsize=(12,12))
plt.imshow(cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# # # Create a new YOLO model from scratch
model = YOLO('yolov8x.yaml')
# # Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8x.pt')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
# ...

# %%
results[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
results[0].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0., 0.])
# conf: tensor([0.7834, 0.7524, 0.6946])
# data: tensor([[209.4262, 281.7703, 218.1081, 321.2837,   0.7834,   0.0000],
#         [118.8357, 200.1387, 126.8074, 225.8065,   0.7524,   0.0000],
#         [420.2416, 167.1961, 427.2290, 196.3006,   0.6946,   0.0000]])
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([3, 6])
# xywh: tensor([[213.7672, 301.5270,   8.6819,  39.5134],
#         [122.8215, 212.9726,   7.9717,  25.6678],
#         [423.7353, 181.7483,   6.9874,  29.1045]])
# xywhn: tensor([[0.3340, 0.4711, 0.0136, 0.0617],
#         [0.1919, 0.3328, 0.0125, 0.0401],
#         [0.6621, 0.2840, 0.0109, 0.0455]])
# xyxy: tensor([[209.4262, 281.7703, 218.1081, 321.2837],
#         [118.8357, 200.1387, 126.8074, 225.8065],
#         [420.2416, 167.1961, 427.2290, 196.3006]])
# xyxyn: tensor([[0.3272, 0.4403, 0.3408, 0.5020],
#         [0.1857, 0.3127, 0.1981, 0.3528],
# ...
